# %%
class expenseTracker:
    def __init__(self):
        self.expenseDict = {
            "income": [],
            "expense": [],
        }

    def store_transactions(self, type, amt, category, date, details):
        trans = {
            "Amount": amt,
            "Category": category,
            "Date": date,
            "Details": details,
        }
        if type == "income":
            self.expenseDict['income'].append(trans)
        else:
            self.expenseDict['expense'].append(trans)

    def view_transactions(self):
        print("Your Income:")
        for item in self.expenseDict['income']:
            print(item)
        print("Your Expenses:")
        for item in self.expenseDict['expense']:
            print(item)

    def calculate_transactions(self):
        total_income = 0
        for item in self.expenseDict['income']:
            total_income += item["Amount"]
        print("Total Income\t:\t", total_income)

        total_expense = 0
        for item in self.expenseDict['expense']:
            total_expense += item["Amount"]
        print("Total Expenses\t:\t", total_expense)

    def store_to_csv(self):
        with open("Lab07.ipynb.csv" , "a+") as file:
            for item in self.expenseDict['income']:
                file.write(str(item),"w+")
            for item in self.expenseDict['expense']:
                file.write(str(item),"w+")
        file.close()


def collectInput():
    amt = int(input("Enter the amout: "))
    category = input("Enter Category: ")
    date = input("Enter Date (DD/MM/YYYY): ")
    details = input("Enter description: ")
    return amt, category, date, details


myexpense = expenseTracker()

while True:
    print("...MY EXPENSE TRACKER...")
    print("1. Record Income")
    print("2. Record Expense")
    print("3. View Records")
    print("4. View My Spendings")
    print("5. Store the details to a csv file.")
    print("6. Exit")

    choice = int(input("Enter your choice: ").strip())

    if choice == 1:
        print("Enter the details of income")
        amt, category, date, details = collectInput()
        myexpense.store_transactions("income", amt, category, date, details)
    elif choice == 2:
        print("Enter the details of expense")
        amt, category, date, details = collectInput()
        myexpense.store_transactions("expense", amt, category, date, details)
    elif choice == 3:
        myexpense.view_transactions()
    elif choice == 4:
        myexpense.calculate_transactions()
    elif choice == 5:
        myexpense.store_to_csv()
    elif choice == 6:
        exit()
    else:
        print("In valid choice")
# Out:
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Store the details to a csv file.
# 6. Exit
# Enter the details of income
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Store the details to a csv file.
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Store the details to a csv file.
# 6. Exit
# Your Income:
# {'Amount': 15000, 'Category': 'Income', 'Date': '10/02/2023', 'Details': 'Salary'}
# Your Expenses:
# {'Amount': 2500, 'Category': 'Expense', 'Date': '05/03/2023', 'Details': 'Fuel'}
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Store the details to a csv file.
# 6. Exit
# Total Income	:	 15000
# Total Expenses	:	 2500
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Store the details to a csv file.
# 6. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\vikas\OneDrive\Desktop\PYTHON\MScDSB-MDS171-23122142-Vikas\Lab07\lab07.ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/vikas/OneDrive/Desktop/PYTHON/MScDSB-MDS171-23122142-Vikas/Lab07/lab07.ipynb#W0sZmlsZQ%3D%3D?line=63'>64</a> print("5. Store the details to a csv file.")
#      <a href='vscode-notebook-cell:/c%3A/Users/vikas/OneDrive/Desktop/PYTHON/MScDSB-MDS171-23122142-Vikas/Lab07/lab07.ipynb#W0sZmlsZQ%3D%3D?line=64'>65</a> print("6. Exit")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vikas/OneDrive/Desktop/PYTHON/MScDSB-MDS171-23122142-Vikas/Lab07/lab07.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a> choice = int(input("Enter your choice: ").strip())
#      <a href='vscode-notebook-cell:/c%3A/Users/vikas/OneDrive/Desktop/PYTHON/MScDSB-MDS171-23122142-Vikas/Lab07/lab07.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a> if choice == 1:
#      <a href='vscode-notebook-cell:/c%3A/Users/vikas/OneDrive/Desktop/PYTHON/MScDSB-MDS171-23122142-Vikas/Lab07/lab07.ipynb#W0sZmlsZQ%3D%3D?line=69'>70</a>     print("Enter the details of income")
#
# ValueError: invalid literal for int() with base 10: ''
